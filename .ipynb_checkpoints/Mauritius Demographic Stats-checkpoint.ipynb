# %%
import pandas as pd
import numpy as np
from IPython.display import display
from pandas import DataFrame
import matplotlib.pyplot as plt
from matplotlib import style
style.use('bmh')
from matplotlib import cm
import math

# %config InlineBackend.figure_formats = {'png', 'retina'}

# %%
# always display all columns in the dataframe 
pd.options.display.max_columns = None

# %%
#function for removing the commas from the database

def my_containsAny(str, set):
    for c in set:
        if c in str: return 1;
    return 0

def remove_commas(df):
    for column in df:
        index = -1
        for i in df[column]:
            index = index +  1
            if type(i) == str:
                #print("this is a string: " + i)
                if my_containsAny(i, ',') == 1:
                    #print("replacing the commas in this string: ", i)
                    i = i.replace(',', '')
                    #print("this no longer has commas: " + i)
                    i = float(i)
                    #print("this was a string but now it is a float: %f, " % (i) )
                    df[column][index] = i
                else: 
                    i = float(i)
                    df[column][index] = i
                    #print("this was a string  but now it is a float: %f" % (i) )
            else:
                print(i)
    return 
# print(df[column])

# %% [markdown]
# ## Life Expectancy

# %%
# life expectancy 
df_lifex = pd.read_csv('life_expectancy_1962.csv')
df_lifex.head()
# Out:
#                                             Contents Unnamed: 1 Unnamed: 2  \
# 0                                                NaN        NaN        NaN
# 1  Table15(c)- Life expectancy at birth1/ by sex ...        NaN        NaN
# 2                                                NaN        NaN        NaN
# 3                                               Year       Male     Female
# 4                                                NaN        NaN        NaN
#
#    Unnamed: 3  Unnamed: 4  Unnamed: 5  Unnamed: 6
# 0         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN         NaN
# 2         NaN         NaN         NaN         NaN
# 3         NaN         NaN         NaN         NaN
# 4         NaN         NaN         NaN         NaN

# %%
# dropping all rows and columns without data 
df_lifex.dropna(axis = 0, how = 'all', inplace = True)
df_lifex.dropna(axis = 1, how = 'all', inplace = True)

df_lifex.drop(labels=[1, 3, 34, 35, 36, 37], inplace = True)
df_lifex.drop(labels=['Contents'], axis = 1, inplace = True)

# create a list to reset the index with 
lifex_years = [1962, 1972, 1982, 1990]
lifex_years = lifex_years + list(range(1991, 2016))

# rename the index and columns 
df_lifex = pd.DataFrame(df_lifex.values, index = lifex_years, columns = ['Male', 'Female'])



# remove commas and turn strings to floats 
remove_commas(df_lifex)
df_lifex = df_lifex.astype(float)

# save to csv
df_lifex.to_pickle('LifeExp.pkl')

df_lifex.head()
# Out:
#        Male  Female
# 1962  58.70   62.00
# 1972  61.00   65.90
# 1982  64.38   71.69
# 1990  65.57   73.39
# 1991  66.15   73.89

# %% [markdown]
# #### Male v Female Life Expectancy Growth Over Time

# %%
df_lifex.plot(linewidth=4, figsize=(15, 5))
plt.xlabel('Years')
plt.ylabel('Life Expectancy')
plt.title('Life Expectancy Growth Over Time')
# Out:
# Text(0.5,1,'Life Expectancy Growth Over Time')

# %% [markdown]
# ## Demographics Over Time

# %%
# demographics over time 
df_demog = pd.read_csv('demographics_age_sex_1998.csv')
df_demog.head()
# Out:
#                                             Contents     Unnamed: 1  \
# 0  Table 18 (a)-Estimated resident population by ...            NaN
# 1                                                NaN            NaN
# 2                                          Age group  1st July 1984
# 3                                                NaN           Male
# 4                                                  0         9,719
#
#   Unnamed: 2  Unnamed: 3     Unnamed: 4 Unnamed: 5  Unnamed: 6     Unnamed: 7  \
# 0        NaN         NaN            NaN        NaN         NaN            NaN
# 1        NaN         NaN            NaN        NaN         NaN            NaN
# 2        NaN         NaN  1st July 1985        NaN         NaN  1st July 1986
# 3     Female  Both sexes           Male     Female  Both sexes           Male
# 4     9,368      19,087          9,288      9,027      18,315          9,047
#
#   Unnamed: 8  Unnamed: 9    Unnamed: 10 Unnamed: 11 Unnamed: 12  \
# 0        NaN         NaN            NaN         NaN         NaN
# 1        NaN         NaN            NaN         NaN         NaN
# 2        NaN         NaN  1st July 1987         NaN         NaN
# 3     Female  Both sexes           Male      Female  Both sexes
# 4     8,712      17,759          9,307       8,935      18,242
#
#      Unnamed: 13 Unnamed: 14 Unnamed: 15    Unnamed: 16 Unnamed: 17  \
# 0            NaN         NaN         NaN            NaN         NaN
# 1            NaN         NaN         NaN            NaN         NaN
# 2  1st July 1988         NaN         NaN  1st July 1989         NaN
# 3           Male      Female  Both sexes           Male      Female
# 4         9,680       9,535      19,215         10,420      10,021
#
#   Unnamed: 18    Unnamed: 19 Unnamed: 20 Unnamed: 21    Unnamed: 22  \
# 0         NaN            NaN         NaN         NaN            NaN
# 1         NaN            NaN         NaN         NaN            NaN
# 2         NaN  1st July 1990         NaN         NaN  1st July 1991
# 3  Both sexes           Male      Female  Both sexes           Male
# 4     20,441         10,323      10,022      20,345         10,803
#
#   Unnamed: 23 Unnamed: 24    Unnamed: 25 Unnamed: 26 Unnamed: 27  \
# 0         NaN         NaN            NaN         NaN         NaN
# 1         NaN         NaN            NaN         NaN         NaN
# 2         NaN         NaN  1st July 1992         NaN         NaN
# 3      Female  Both sexes           Male      Female  Both sexes
# 4     10,432      21,235         11,218      10,624      21,842
#
#      Unnamed: 28 Unnamed: 29 Unnamed: 30    Unnamed: 31 Unnamed: 32  \
# 0            NaN         NaN         NaN            NaN         NaN
# 1            NaN         NaN         NaN            NaN         NaN
# 2  1st July 1993         NaN         NaN  1st July 1994         NaN
# 3           Male      Female  Both sexes           Male      Female
# 4        10,817      10,747      21,564         10,392      10,255
#
#   Unnamed: 33    Unnamed: 34 Unnamed: 35 Unnamed: 36    Unnamed: 37  \
# 0         NaN            NaN         NaN         NaN            NaN
# 1         NaN            NaN         NaN         NaN            NaN
# 2         NaN  1st July 1995         NaN         NaN  1st July 1996
# 3  Both sexes           Male      Female  Both sexes           Male
# 4     20,647         10,290      10,175      20,465          9,755
#
#   Unnamed: 38 Unnamed: 39    Unnamed: 40 Unnamed: 41 Unnamed: 42  \
# 0         NaN         NaN            NaN         NaN         NaN
# 1         NaN         NaN            NaN         NaN         NaN
# 2         NaN         NaN  1st July 1997         NaN         NaN
# 3      Female  Both sexes           Male      Female  Both sexes
# 4      9,567      19,322          9,643       9,567      19,210
#
#      Unnamed: 43 Unnamed: 44 Unnamed: 45    Unnamed: 46 Unnamed: 47  \
# 0            NaN         NaN         NaN            NaN         NaN
# 1            NaN         NaN         NaN            NaN         NaN
# 2  1st July 1998         NaN         NaN  1st July 1999         NaN
# 3           Male      Female  Both sexes           Male      Female
# 4         9,640       9,292      18,932          9,580       9,107
#
#   Unnamed: 48    Unnamed: 49 Unnamed: 50 Unnamed: 51    Unnamed: 52  \
# 0         NaN            NaN         NaN         NaN            NaN
# 1         NaN            NaN         NaN         NaN            NaN
# 2         NaN  1st July 2000         NaN         NaN  1st July 2001
# 3  Both sexes           Male      Female  Both sexes           Male
# 4     18,687          9,719       9,290      19,009          9,671
#
#   Unnamed: 53 Unnamed: 54    Unnamed: 55 Unnamed: 56 Unnamed: 57  \
# 0         NaN         NaN            NaN         NaN         NaN
# 1         NaN         NaN            NaN         NaN         NaN
# 2         NaN         NaN  1st July 2002         NaN         NaN
# 3      Female  Both sexes           Male      Female  Both sexes
# 4      9,326      18,997          9,638       9,246      18,884
#
#      Unnamed: 58 Unnamed: 59 Unnamed: 60    Unnamed: 61 Unnamed: 62  \
# 0            NaN         NaN         NaN            NaN         NaN
# 1            NaN         NaN         NaN            NaN         NaN
# 2  1st July 2003         NaN         NaN  1st July 2004         NaN
# 3           Male      Female  Both sexes           Male      Female
# 4         9,620       9,267      18,887          9,575       9,229
#
#   Unnamed: 63    Unnamed: 64 Unnamed: 65 Unnamed: 66    Unnamed: 67  \
# 0         NaN            NaN         NaN         NaN            NaN
# 1         NaN            NaN         NaN         NaN            NaN
# 2         NaN  1st July 2005         NaN         NaN  1st July 2006
# 3  Both sexes           Male      Female  Both sexes           Male
# 4     18,804          9,441       9,143      18,584          9,242
#
#   Unnamed: 68 Unnamed: 69    Unnamed: 70 Unnamed: 71 Unnamed: 72  \
# 0         NaN         NaN            NaN         NaN         NaN
# 1         NaN         NaN            NaN         NaN         NaN
# 2         NaN         NaN  1st July 2007         NaN         NaN
# 3      Female  Both sexes           Male      Female  Both sexes
# 4      8,931      18,173          9,014       8,675      17,689
#
#      Unnamed: 73 Unnamed: 74 Unnamed: 75    Unnamed: 76 Unnamed: 77  \
# 0            NaN         NaN         NaN            NaN         NaN
# 1            NaN         NaN         NaN            NaN         NaN
# 2  1st July 2008         NaN         NaN  1st July 2009         NaN
# 3           Male      Female  Both sexes           Male      Female
# 4         8,693       8,361      17,054          8,324       8,068
#
#   Unnamed: 78    Unnamed: 79 Unnamed: 80 Unnamed: 81    Unnamed: 82  \
# 0         NaN            NaN         NaN         NaN            NaN
# 1         NaN            NaN         NaN         NaN            NaN
# 2         NaN  1st July 2010         NaN         NaN  1st July 2011
# 3  Both sexes           Male      Female  Both sexes           Male
# 4     16,392          7,957       7,723      15,680          6,973
#
#   Unnamed: 83 Unnamed: 84    Unnamed: 85 Unnamed: 86 Unnamed: 87  \
# 0         NaN         NaN            NaN         NaN         NaN
# 1         NaN         NaN            NaN         NaN         NaN
# 2         NaN         NaN  1st July 2012         NaN         NaN
# 3      Female  Both sexes           Male      Female  Both sexes
# 4      6,826      13,799          6,971       6,805      13,776
#
#      Unnamed: 88 Unnamed: 89 Unnamed: 90    Unnamed: 91 Unnamed: 92  \
# 0            NaN         NaN         NaN            NaN         NaN
# 1            NaN         NaN         NaN            NaN         NaN
# 2  1st July 2013         NaN         NaN  1st July 2014         NaN
# 3           Male      Female  Both sexes           Male      Female
# 4         6,762       6,397      13,159          6,497       6,327
#
#   Unnamed: 93    Unnamed: 94 Unnamed: 95 Unnamed: 96    Unnamed: 97  \
# 0         NaN            NaN         NaN         NaN            NaN
# 1         NaN            NaN         NaN         NaN            NaN
# 2         NaN  1st July 2015         NaN         NaN  1st July 2016
# 3  Both sexes           Male      Female  Both sexes           Male
# 4     12,824          6,301       6,066      12,367          6,168
#
#   Unnamed: 98 Unnamed: 99
# 0         NaN         NaN
# 1         NaN         NaN
# 2         NaN         NaN
# 3      Female  Both sexes
# 4      5,811      11,979

# %%
# dropping all rows and columns without data 
df_demog.dropna(axis = 0, how = 'all', inplace = True)
df_demog.dropna(axis = 1, how = 'all', inplace = True)

df_demog.drop(labels=[0, 2, 3, 24, 25, 26, 27], inplace = True)

# reset the index
df_demog.set_index('Contents', inplace = True)
df_demog.index.rename('Age Group', inplace = True)

# remove commas and turn strings to floats 
remove_commas(df_demog)

# %%
# creating a new transposed matrix
df_demog_T = df_demog.transpose()

# creating lists for a new multi-level index 
years = list(range(1984,2017))
sexes = ['Male', 'Female', 'Both Sexes']
new_index = pd.MultiIndex.from_product([years, sexes], names = ['Years', 'Sexes'])

# creating a new dataframe with the new index
df_demogn = pd.DataFrame(df_demog_T.values, index = new_index, columns = list(df_demog_T.columns))

# save to csv
df_demogn.to_csv('Demographics.csv')

df_demogn.head()
# Out:
#                       0  1 - 4   5 - 9 10 - 14 15 - 19 20 - 24 25 - 29  \
# Years Sexes
# 1984  Male         9719  45334   54756   48151   54919   54506   46605
#       Female       9368  43692   52484   46678   53987   53953   45671
#       Both Sexes  19087  89026  107240   94829  108906  108459   92276
# 1985  Male         9288  42804   56458   48310   53751   55607   47586
#       Female       9027  40612   53959   46895   52013   54307   46990
#
#                  30 - 34 35 - 39 40 - 44 45 - 49 50 - 54 55 - 59 60 - 64  \
# Years Sexes
# 1984  Male         40744   28032   21121   19411   16801   16940   12720
#       Female       39800   29441   22264   19403   16320   16695   13301
#       Both Sexes   80544   57473   43385   38814   33121   33635   26021
# 1985  Male         40933   29662   22329   19992   17467   16797   14138
#       Female       40211   30401   23496   19683   16899   16411   14212
#
#                  65 - 69 70 - 74 75 - 79 80 - 84  85 + All ages
# Years Sexes
# 1984  Male          8645    5585    2846    1095   419   488349
#       Female        9721    7281    4495    2670  1556   488780
#       Both Sexes   18366   12866    7341    3765  1975   977129
# 1985  Male          8477    5862    2799    1217   423   493900
#       Female        9725    7561    4527    2735  1646   491310

# %%
# index slice function
idx = pd.IndexSlice

# matrix that only looks at ages for both sexes
df_demogn_both = df_demogn.loc[idx['1984':'2016','Both Sexes'],:]

# matrix that also drops the 'all ages' column 
df_demogn_all = df_demogn_both.drop(labels = 'All ages', axis = 1)

df_demogn_all.head()
# Out:
#                       0  1 - 4   5 - 9 10 - 14 15 - 19 20 - 24 25 - 29  \
# Years Sexes
# 1984  Both Sexes  19087  89026  107240   94829  108906  108459   92276
# 1985  Both Sexes  18315  83416  110417   95205  105764  109914   94576
# 1986  Both Sexes  17759  78141  113289   95247  100801  112085   94632
# 1987  Both Sexes  18242  74241  114271   98226   97121  109941   99116
# 1988  Both Sexes  19215  72466  111231  103746   93742  107363  102784
#
#                  30 - 34 35 - 39 40 - 44 45 - 49 50 - 54 55 - 59 60 - 64  \
# Years Sexes
# 1984  Both Sexes   80544   57473   43385   38814   33121   33635   26021
# 1985  Both Sexes   81144   60063   45825   39675   34366   33208   28350
# 1986  Both Sexes   82667   68414   47725   38974   36159   31805   30243
# 1987  Both Sexes   85095   72452   49200   38482   38401   30860   30571
# 1988  Both Sexes   87261   75737   52359   40148   39362   31099   30310
#
#                  65 - 69 70 - 74 75 - 79 80 - 84  85 +
# Years Sexes
# 1984  Both Sexes   18366   12866    7341    3765  1975
# 1985  Both Sexes   18202   13423    7326    3952  2069
# 1986  Both Sexes   18493   13631    7547    4098  2141
# 1987  Both Sexes   19361   14416    7400    4198  2200
# 1988  Both Sexes   20545   14831    7858    4053  2486

# %%
df_demogn_all.loc[1985, 'Both Sexes'].describe(include = all)
# Out:
# count        19.0
# unique       19.0
# top       60063.0
# freq          1.0
# Name: (1985, Both Sexes), dtype: float64

# %%
fig = plt.figure(figsize=(20,8))



plt.bar(df_demogn_all.columns, df_demogn_all.loc[1985, 'Both Sexes'], label = 1985, width = 0.8)
plt.bar(df_demogn_all.columns, df_demogn_all.loc[1995, 'Both Sexes'], label = 1995, width = 0.60)
plt.bar(df_demogn_all.columns, df_demogn_all.loc[2005, 'Both Sexes'], label = 2005, width = 0.35)
plt.bar(df_demogn_all.columns, df_demogn_all.loc[2015, 'Both Sexes'], label = 2015, width = 0.15, color = 'orange')


plt.ylabel('Ages')
plt.xlabel('Population')
plt.title('Age Distribution Per Decade')
plt.legend()

# %% [markdown]
# #### Population Growth Over Time

# %%
df_demogn_both['All ages'].plot(figsize=(30,10), linewidth=4)
df_lifex.plot(linewidth=4, figsize=(15, 5))
plt.xlabel('Years')
plt.ylabel('Life Expectancy')
plt.title('Life Expectancy Growth Over Time')

# %% [markdown]
# #### Age Distribution Over Time

# %%
x85 = df_demogn_all.loc[1985, 'Both Sexes']
x95 = df_demogn_all.loc[1995, 'Both Sexes']
x2005 = df_demogn_all.loc[2005, 'Both Sexes']
x2015 = df_demogn_all.loc[2015, 'Both Sexes']



fig, axes = plt.subplots(4,1,  figsize=(7,15))

cs=cm.Set1(np.arange(100)/18.)


axes[0].hist(x85, colors=cs)
axes[0].set_title("1985")
axes[1].pie(x95, colors=cs)
axes[1].set_title("1995")
axes[2].pie(x2005, colors=cs)
axes[2].set_title("2005")
axes[3].pie(x2015, colors=cs)
axes[3].set_title("2015")


#plt.title("Change in distribution of industry with respect to GDP")
#plt.figlegend(list(df_GDP2.columns))
plt.figlegend(list(df_demogn_all.columns))


plt.show
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-151-33ce1904f56b> in <module>()
#      11
#      12
# ---> 13 axes[0].hist(x85, colors=cs)
#      14 axes[0].set_title("1985")
#      15 axes[1].pie(x95, colors=cs)
#
# ~/miniconda3/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
#    1853                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1854                         RuntimeWarning, stacklevel=2)
# -> 1855             return func(ax, *args, **kwargs)
#    1856
#    1857         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# ~/miniconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py in hist(***failed resolving arguments***)
#    6716             if patch:
#    6717                 p = patch[0]
# -> 6718                 p.update(kwargs)
#    6719                 if lbl is not None:
#    6720                     p.set_label(lbl)
#
# ~/miniconda3/lib/python3.6/site-packages/matplotlib/artist.py in update(self, props)
#     886         try:
#     887             ret = [_update_property(self, k, v)
# --> 888                    for k, v in props.items()]
#     889         finally:
#     890             self.eventson = store
#
# ~/miniconda3/lib/python3.6/site-packages/matplotlib/artist.py in <listcomp>(.0)
#     886         try:
#     887             ret = [_update_property(self, k, v)
# --> 888                    for k, v in props.items()]
#     889         finally:
#     890             self.eventson = store
#
# ~/miniconda3/lib/python3.6/site-packages/matplotlib/artist.py in _update_property(self, k, v)
#     879                 func = getattr(self, 'set_' + k, None)
#     880                 if not callable(func):
# --> 881                     raise AttributeError('Unknown property %s' % k)
#     882                 return func(v)
#     883
#
# AttributeError: Unknown property colors
